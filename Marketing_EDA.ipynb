# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/GreenBox/blob/main/Marketing_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
import pandas as pd
import plotly.express as px
import numpy as np
from scipy.stats import chi2_contingency

# %%
df_users = pl.read_csv('greenbox_users.csv')
df_spend = pl.read_csv('greenbox_spend.csv')
df_events = pl.read_csv('greenbox_events.csv')

# %% [markdown]
# # **Analysis 1: The Marketing Funnel**

# %% [markdown]
# **Goal: How many users do we have in each step: View -> Cart -> Checkout -> Purchase**

# %%
funnel_data = (
    df_events
    .group_by('event_name')
    .agg(pl.col('user_id').n_unique().alias('user_count'))
)

# %%
# Defining the order
funnel_order = ['view_landing_page','add_to_cart','checkouts_start','purchase']

# %%
# Sorting the data using a mapping strategy (Using Polars)
pdf_funnel = funnel_data.to_pandas()
pdf_funnel['event_name'] = pd.Categorical(pdf_funnel['event_name'], categories=funnel_order, ordered=True)
pdf_funnel= pdf_funnel.sort_values('event_name')

# %%
fig_funnel = px.funnel(
    pdf_funnel,
    x='user_count',
    y='event_name',
    title='GreenBox Marketing Conversion Funnel',
    color='event_name'
)
fig_funnel.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="45c18f34-7694-4b33-90f7-e0d7ce441ea6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45c18f34-7694-4b33-90f7-e0d7ce441ea6")) {                    Plotly.newPlot(                        "45c18f34-7694-4b33-90f7-e0d7ce441ea6",                        [{"hovertemplate":"event_name=%{y}\u003cbr\u003euser_count=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"view_landing_page","marker":{"color":"#636efa"},"name":"view_landing_page","orientation":"v","showlegend":true,"x":[10000],"xaxis":"x","y":["view_landing_page"],"yaxis":"y","type":"funnel"},{"hovertemplate":"event_name=%{y}\u003cbr\u003euser_count=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"add_to_cart","marker":{"color":"#EF553B"},"name":"add_to_cart","orientation":"v","showlegend":true,"x":[6016],"xaxis":"x","y":["add_to_cart"],"yaxis":"y","type":"funnel"},{"hovertemplate":"event_name=%{y}\u003cbr\u003euser_count=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"purchase","marker":{"color":"#00cc96"},"name":"purchase","orientation":"v","showlegend":true,"x":[773],"xaxis":"x","y":["purchase"],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"over ...

# %% [markdown]
# # **Analysis 2: Revenue by Channel (With Polars Join)**

# %%
revenue_df = (
    df_users
    .join(df_events, on='user_id',how='left')
    .filter(pl.col('event_name')== 'purchase')
    .group_by('acquisition_channel')
    .agg(pl.col('revenue').sum().alias('total_revenue'))
    .sort('total_revenue',descending=True)
)

display(revenue_df)
# Out:
# shape: (6, 2)
# ┌─────────────────────┬───────────────┐
# │ acquisition_channel ┆ total_revenue │
# │ ---                 ┆ ---           │
# │ str                 ┆ f64           │
# ╞═════════════════════╪═══════════════╡
# │ Facebook            ┆ 32193.56      │
# │ TikTok              ┆ 21695.66      │
# │ Google Ads          ┆ 21595.68      │
# │ Instagram           ┆ 17546.49      │
# │ Organic             ┆ 10997.8       │
# │ Referral            ┆ 6498.7        │
# └─────────────────────┴───────────────┘

# %%
fig_rev = px.bar(
    revenue_df.to_pandas(),
    x='acquisition_channel',
    y='total_revenue',
    color='acquisition_channel',
    title='Total Revenue by Acquisition Channel',
    text_auto='.2s'
)

fig_rev.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dfa6527b-62f2-40d8-bf0c-7df113e3459b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfa6527b-62f2-40d8-bf0c-7df113e3459b")) {                    Plotly.newPlot(                        "dfa6527b-62f2-40d8-bf0c-7df113e3459b",                        [{"alignmentgroup":"True","hovertemplate":"acquisition_channel=%{x}\u003cbr\u003etotal_revenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Facebook","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Facebook","offsetgroup":"Facebook","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Facebook"],"xaxis":"x","y":[32193.559999999914],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"acquisition_channel=%{x}\u003cbr\u003etotal_revenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TikTok","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"TikTok","offsetgroup":"TikTok","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["TikTok"],"xaxis":"x","y":[21695.659999999923],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"acquisition_channel=%{x}\u003cbr\u003etotal_revenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Google Ads","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Google Ads","offsetgroup":"Google Ads","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Google Ads"],"xaxis":"x","y":[21595.679999999924],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"acquisition_channel=%{x}\u003cbr\u003etotal_revenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Instagram","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Instagram","offsetgroup":"Instagram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Instagram"],"xaxis":"x","y":[17546.48999999994],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"acquisition_channel=%{x}\u003cbr\u003etotal_revenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Organic","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Organic","offsetgroup":"Organic","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Organic"],"xaxis":"x","y":[10997.79999999997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"acquisition_channel=%{x}\u003cbr\u003etotal_revenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Referral","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Referral","offsetgroup":"Referral","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Referral"],"xaxis":"x","y":[6498.69999999999],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap ...

# %% [markdown]
# # **Analysis 3: A/B Test Statistics**

# %%
purchased_user_ids = df_events.filter(pl.col('event_name') == 'purchase').select('user_id').unique()

ab_data = df_users.with_columns(
    pl.col('user_id').is_in(purchased_user_ids['user_id']).alias('did_convert')
)

# Group by Group + Converted Status
stats_summary = (
    ab_data.group_by(['ab_test_group', 'did_convert'])
    .len()
    .sort('ab_test_group')
)

display(stats_summary)
# Out:
# /tmp/ipython-input-3508530834.py:3: DeprecationWarning:
#
# `is_in` with a collection of the same datatype is ambiguous and deprecated.
# Please use `implode` to return to previous behavior.
#
# See https://github.com/pola-rs/polars/issues/22149 for more information.
# shape: (4, 3)
# ┌───────────────┬─────────────┬──────┐
# │ ab_test_group ┆ did_convert ┆ len  │
# │ ---           ┆ ---         ┆ ---  │
# │ str           ┆ bool        ┆ u32  │
# ╞═══════════════╪═════════════╪══════╡
# │ Control       ┆ false       ┆ 4683 │
# │ Control       ┆ true        ┆ 323  │
# │ Variant       ┆ true        ┆ 450  │
# │ Variant       ┆ false       ┆ 4544 │
# └───────────────┴─────────────┴──────┘

# %%
# Extracting counts for SciPy
control_conv = ab_data.filter((pl.col('ab_test_group')== 'Control') & (pl.col('did_convert') == True)).height
control_not = ab_data.filter((pl.col('ab_test_group') == 'Control') & (pl.col('did_convert') == False)).height
variant_conv = ab_data.filter((pl.col("ab_test_group") == "Variant") & (pl.col("did_convert") == True)).height
variant_not = ab_data.filter((pl.col("ab_test_group") == "Variant") & (pl.col("did_convert") == False)).height

# %%
# Chi-Square Test
observed = np.array([
    [control_conv, control_not],
    [variant_conv, variant_not]
])

chi2,p,dof,expected = chi2_contingency(observed)

print(f"\nSignificance Test Results:")
print(f"Control Conversion: {control_conv} / {control_conv + control_not}")
print(f"Variant Conversion: {variant_conv} / {variant_conv + variant_not}")
print(f"P-Value: {p:.2f}")

if p < 0.05:
  print('RESULT: Statistically Significant! The Varient is truly better')
else:
  print('RESULT: Not Significant. The difference could be luck.')
# Out:
# Significance Test Results:
# Control Conversion: 323 / 5006
# Variant Conversion: 450 / 4994
# P-Value: 0.00
# RESULT: Statistically Significant! The Varient is truly better
